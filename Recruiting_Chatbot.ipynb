# %%
print('Hello and welcome to Awesome Jobs.')
print('We will together find a better job for you.\n\n')

print("------------------------------")
name   =     input("Tell me, what is your full name?\n")
city   =     input("\nWhich city are you from?\n")
gender =     input("\nGreat. What's your gender?\n")
age    =     input("\nHow old are you?\n")
print("------------------------------")

print('\nThis is exciting.')
print('\nI already have found more than 300 jobs that you might like.')

job_types = ["driver", "maid", "cook", "repair person", "delivery person"]
salary_range = [ "15K - 20K","21K - 25K","26K - 30K","31K - 36K" ]

print("\n\nWhat kind of jobs do you like?")
for i in job_types :
  print("-- "+i)

job   =  input("\nPlease enter your job preference \n")

print("\n\nHow much monthly salary do you expect?")
for i in salary_range :
  print("-- "+i)

salary = input("\nPlease enter your salary preference \n")

jobs = { 1: {'job': 'driver', 'company': 'uber', 'salary': '26K-30K'},
         2: {'job': 'maid', 'company': 'urbanclap', 'salary': '21K-25K'},
         3: {'job': 'cook', 'company': 'foodfever', 'salary': '15K-20K' },
         4: {'job': 'repair person', 'company': 'funtools', 'salary': '31K-36K' },
         5: {'job': 'delivery person', 'company': 'blue cart', 'salary': '15K-20K' }}

print('\n\n')
print("----------------User Details---------------")

print("Name                 : ",name)
print("Age                  : ",age)
print("Gender               : ",gender)
print("City                 : ",city)
print("Job Role             : ",job)
print("Salary Expectations  : ",salary)
print("--------------------------------------------")

print("\n\n********************************************\n\n")

print('Great. Here’s a list of great jobs we have available.')
print('\n')

for j in jobs.keys():
   if (jobs[j]['job'] == job):
       print( jobs[j] )
       break
   
print('\n')
select = input('If you like them, type yes or no to apply for it : ')

if( select == 'yes') :
   print('\nYour application has been successfully sent to ', jobs[j]['company'])
   print('\nYou’ve picked', jobs[j]['company'], ',Great choice!')
   print('\nThe next step is to schedule your interview with them.')
   print('\nIt was great talking to you.')
   print('\nThe exployer will contact you to get more information about your job application')

   details = name+","+age+","+city+","+job+","+salary+"\n"
   fd = open("Record.txt",'a')
   fd.write(details)
   fd.close()

   print("\n\nYour Details are saved!")

else:
   print("\nThank you for your Time, Please visit next time to get updated job offers.")
# Out:
# Hello and welcome to Awesome Jobs.
# We will together find a better job for you.
#
#
# ------------------------------
# Tell me, what is your full name?
# Mili Jolly
#
# Which city are you from?
# Delhi
#
# Great. What's your gender?
# Female
#
# How old are you?
# 21
# ------------------------------
#
# This is exciting.
#
# I already have found more than 300 jobs that you might like.
#
#
# What kind of jobs do you like?
# -- driver
# -- maid
# -- cook
# -- repair person
# -- delivery person
#
# Please enter your job preference
# driver
#
#
# How much monthly salary do you expect?
# -- 15K - 20K
# -- 21K - 25K
# -- 26K - 30K
# -- 31K - 36K
#
# Please enter your salary preference
# 21K -25K
#
#
#
# ----------------User Details---------------
# Name                 :  Mili Jolly
# Age                  :  21
# Gender               :  Female
# City                 :  Delhi
# Job Role             :  driver
# Salary Expectations  :  21K -25K
# --------------------------------------------
# ...
